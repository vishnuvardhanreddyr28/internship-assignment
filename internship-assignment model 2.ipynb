# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import pydicom
import pandas as pd
import numpy as np 
import random
import tensorflow as tf 
import matplotlib.pyplot as plt 
import random
from tqdm.notebook import tqdm 
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_absolute_error
from tensorflow_addons.optimizers import RectifiedAdam
from tensorflow.keras import Model
import tensorflow.keras.backend as K
import tensorflow.keras.layers as L
import tensorflow.keras.models as M
from tensorflow.keras.optimizers import Nadam
from keras.layers import Dense, Conv2D, MaxPooling2D,Flatten,GlobalAveragePooling2D
import seaborn as sns
from tensorflow.keras.utils import Sequence
from PIL import Image
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import layers
from tensorflow.keras.layers import LeakyReLU
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('../input/deepweedsx/train_set_labels.csv')
df.head()
# Out:
#                    Label  Species
# 0  20161207-111327-0.jpg        0
# 1  20170718-095159-2.jpg        0
# 2  20170811-133439-1.jpg        0
# 3  20170811-133752-1.jpg        0
# 4  20170217-114015-0.jpg        0

# %%
import matplotlib.pyplot as plt
img=plt.imread('../input/deepweedsx/DeepWeeds_Images_256/20161207-111327-0.jpg')
plt.imshow(img)

# %%
class IGenerator(Sequence):
    def __init__(self,df,batch_size=16):
        self.keys=df.Label
        self.batch_size=batch_size
        self.df=df
        self.train_data = {}
        
            
    def __len__(self):
        return 1000
    
    def __getitem__(self,idx):
        
        imagedata=[]
        y=[]
        
        keys = np.random.choice(self.keys, size = self.batch_size)
        
        for k in keys:
            try:
                image='../input/deepweedsx/DeepWeeds_Images_256/'+str(k)
                image=plt.imread(image)
                imagedata.append(image)
                
                
                
                y.append(self.df.loc[self.df.Label==k].Species.values)
                
            except:
                pass
       
        imagedata,y = np.array(imagedata),np.array(y)
        y=y.reshape(-1,)
        
        
        
      
        return imagedata , y

# %%
import sys
sys.path.append('../input/mobilenet-v3/MobileNetV3-master/MobileNetV3-master/model/layers')
sys.path.append('../input/mobilenet-v3/MobileNetV3-master/MobileNetV3-master/model')
sys.path.append('../input/mobilenet-v3/MobileNetV3-master/MobileNetV3-master')

# %%
import mobilenet_v3_small
import mobilenet_v3_large
from mobilenet_v3_small import MobileNetV3_Small
from mobilenet_v3_large import MobileNetV3_Large

# %%
def build_model(input_dim=256):
    input1 = tf.keras.layers.Input(shape=(input_dim,input_dim,3))
    model=MobileNetV3_Large([256,256,3],9,include_top=False)
    basemodel=model.build()
    x=basemodel.output
    x=GlobalAveragePooling2D()(x)
    x=Dense(1024,activation='relu')(x)  
    x=Dense(512,activation='relu')(x) 
    preds=Dense(9,activation='softmax')(x) 
    model=Model(inputs=basemodel.input,outputs=preds)
    return model

# %%
model=build_model(256)

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 272         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 128, 128, 16) 160         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 16) 64          depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 272         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 16) 0           batch_normalization_3[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 1088        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 64, 64, 64)   640         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 24)   1560        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 24)   96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 72)   1800        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 72)   288         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 72)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 64, 64, 72)   720         activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 72)   288         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 72)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 24)   1752        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 24)   96          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 24)   0           batch_normalization_9[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 72)   1800        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 72)   288         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 72)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 32, 32, 72)   1872        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 72)   288         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 72)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 72)           0           activation_8[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 72)           5256        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 72)           5256        dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 72)     0           dense_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 32, 32, 72)   0           activation_8[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 40)   2920        multiply[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 40)   160         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 120)  4920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 120)  480         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 120)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 32, 32, 120)  3120        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 120)  480         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 120)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 120)          0           activation_10[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 120)          14520       global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 120)          14520       dense_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 120)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 32, 32, 120)  0           activation_10[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 40)   4840        multiply_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 40)   160         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 40)   0           batch_normalization_15[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 120)  4920        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 120)  480         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 120)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 32, 32, 120)  3120        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 120)  480         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 120)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 120)          0           activation_12[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 120)          14520       global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 120)          14520       dense_4[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 120)    0           dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 32, 32, 120)  0           activation_12[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 40)   4840        multiply_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 40)   160         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 40)   0           batch_normalization_18[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 240)  9840        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 240)  960         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 240)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 16, 16, 240)  2400        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 240)  960         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 240)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 80)   19280       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 80)   320         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 200)  16200       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 200)  800         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 200)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 16, 16, 200)  2000        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 200)  800         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 200)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 80)   16080       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 80)   320         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 80)   0           batch_normalization_24[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 184)  14904       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 184)  736         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 184)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 16, 16, 184)  1840        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 184)  736         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 184)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 80)   14800       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 80)   320         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 80)   0           batch_normalization_27[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 184)  14904       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 184)  736         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 184)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 16, 16, 184)  1840        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 184)  736         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 184)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 80)   14800       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 80)   320         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 80)   0           batch_normalization_30[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 480)  38880       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 480)  1920        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 480)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 16, 16, 480)  4800        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 480)  1920        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 480)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 480)          0           activation_22[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 480)          230880      global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 480)          230880      dense_6[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 480)    0           dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 16, 16, 480)  0           activation_22[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 112)  53872       multiply_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 112)  448         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 672)  75936       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 672)  2688        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 672)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 16, 16, 672)  6720        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 672)  2688        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 672)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 672)          0           activation_24[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 672)          452256      global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 672)          452256      dense_8[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 672)    0           dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 16, 16, 672)  0           activation_24[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 112)  75376       multiply_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 112)  448         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 112)  0           batch_normalization_36[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 672)  75936       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 16, 16, 672)  2688        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 672)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 8, 8, 672)    17472       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 672)    2688        depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 672)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 672)          0           activation_26[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 672)          452256      global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 672)          452256      dense_10[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 672)    0           dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 8, 8, 672)    0           activation_26[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 160)    107680      multiply_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 160)    640         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 960)    154560      batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 960)    3840        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 960)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 8, 8, 960)    24960       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 960)    3840        depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 960)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 960)          0           activation_28[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 960)          922560      global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 960)          922560      dense_12[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 960)    0           dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 8, 8, 960)    0           activation_28[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 160)    153760      multiply_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 160)    640         conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 160)    0           batch_normalization_42[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 960)    154560      add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 960)    3840        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 960)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 8, 8, 960)    24960       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 8, 960)    3840        depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 960)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 960)          0           activation_30[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 960)          922560      global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 960)          922560      dense_14[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 960)    0           dense_15[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 8, 8, 960)    0           activation_30[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 160)    153760      multiply_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 160)    640         conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 160)    0           batch_normalization_45[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 960)    154560      add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 8, 960)    3840        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 960)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 960)          0           activation_31[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 960)    0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 1, 1, 1280)   1230080     reshape_8[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 1, 1, 1280)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 1280)         0           activation_32[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1024)         1311744     global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 512)          524800      dense_16[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 9)            4617        dense_17[0][0]
# ==================================================================================================
# Total params: 10,597,465
# Trainable params: 10,573,033
# Non-trainable params: 24,432
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam',loss= tf.keras.losses.SparseCategoricalCrossentropy(),metrics=['accuracy'])

# %%
validdf=pd.read_csv('../input/deepweedsx/test_set_labels.csv')
validdf.head()
# Out:
#                    Label  Species
# 0  20160928-141107-0.jpg        0
# 1  20160928-141135-0.jpg        0
# 2  20161207-110730-0.jpg        0
# 3  20161207-110850-0.jpg        0
# 4  20161207-112015-0.jpg        0

# %%
filepath = "./model.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=2, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
print(len(df))
print(len(validdf))
# Out:
# 15007
# 2501

# %%
history=model.fit(IGenerator(df=df),steps_per_epoch =900,epochs=50,verbose=1,validation_data=IGenerator(df=validdf),validation_steps=150,callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 900/900 [==============================] - ETA: 0s - loss: 1.4283 - accuracy: 0.5275
# Epoch 00001: val_accuracy improved from -inf to 0.21542, saving model to ./model.hdf5
# 900/900 [==============================] - 174s 194ms/step - loss: 1.4283 - accuracy: 0.5275 - val_loss: 2.1939 - val_accuracy: 0.2154
# Epoch 2/50
# 900/900 [==============================] - ETA: 0s - loss: 1.2188 - accuracy: 0.5631
# Epoch 00002: val_accuracy improved from 0.21542 to 0.56667, saving model to ./model.hdf5
# 900/900 [==============================] - 131s 145ms/step - loss: 1.2188 - accuracy: 0.5631 - val_loss: 1.2794 - val_accuracy: 0.5667
# Epoch 3/50
# 900/900 [==============================] - ETA: 0s - loss: 1.1308 - accuracy: 0.5856
# Epoch 00003: val_accuracy did not improve from 0.56667
# 900/900 [==============================] - 115s 128ms/step - loss: 1.1308 - accuracy: 0.5856 - val_loss: 1.3052 - val_accuracy: 0.5188
# Epoch 4/50
# 900/900 [==============================] - ETA: 0s - loss: 1.0771 - accuracy: 0.6067
# Epoch 00004: val_accuracy improved from 0.56667 to 0.57833, saving model to ./model.hdf5
# 900/900 [==============================] - 112s 124ms/step - loss: 1.0771 - accuracy: 0.6067 - val_loss: 1.1309 - val_accuracy: 0.5783
# Epoch 5/50
# 900/900 [==============================] - ETA: 0s - loss: 1.0074 - accuracy: 0.6298
# Epoch 00005: val_accuracy improved from 0.57833 to 0.60417, saving model to ./model.hdf5
# 900/900 [==============================] - 111s 123ms/step - loss: 1.0074 - accuracy: 0.6298 - val_loss: 1.0999 - val_accuracy: 0.6042
# Epoch 6/50
# 900/900 [==============================] - ETA: 0s - loss: 0.9928 - accuracy: 0.6371
# Epoch 00006: val_accuracy did not improve from 0.60417
# 900/900 [==============================] - 110s 122ms/step - loss: 0.9928 - accuracy: 0.6371 - val_loss: 2.0005 - val_accuracy: 0.3929
# Epoch 7/50
# 900/900 [==============================] - ETA: 0s - loss: 0.9567 - accuracy: 0.6501
# Epoch 00007: val_accuracy improved from 0.60417 to 0.63000, saving model to ./model.hdf5
# 900/900 [==============================] - 110s 122ms/step - loss: 0.9567 - accuracy: 0.6501 - val_loss: 1.1999 - val_accuracy: 0.6300
# Epoch 8/50
# 900/900 [==============================] - ETA: 0s - loss: 0.8993 - accuracy: 0.6727
# Epoch 00008: val_accuracy improved from 0.63000 to 0.67292, saving model to ./model.hdf5
# 900/900 [==============================] - 111s 124ms/step - loss: 0.8993 - accuracy: 0.6727 - val_loss: 0.8957 - val_accuracy: 0.6729
# Epoch 9/50
# 900/900 [==============================] - ETA: 0s - loss: 0.8851 - accuracy: 0.6736
# Epoch 00009: val_accuracy did not improve from 0.67292
# 900/900 [==============================] - 108s 120ms/step - loss: 0.8851 - accuracy: 0.6736 - val_loss: 1.1089 - val_accuracy: 0.6079
# Epoch 10/50
# 900/900 [==============================] - ETA: 0s - loss: 0.8352 - accuracy: 0.6957
# Epoch 00010: val_accuracy did not improve from 0.67292
# 900/900 [==============================] - 109s 121ms/step - loss: 0.8352 - accuracy: 0.6957 - val_loss: 0.9059 - val_accuracy: 0.6712
# Epoch 11/50
# 900/900 [==============================] - ETA: 0s - loss: 0.7916 - accuracy: 0.7145
# Epoch 00011: val_accuracy improved from 0.67292 to 0.70708, saving model to ./model.hdf5
# 900/900 [==============================] - 112s 124ms/step - loss: 0.7916 - accuracy: 0.7145 - val_loss: 0.8100 - val_accuracy: 0.7071
# Epoch 12/50
# 900/900 [==============================] - ETA: 0s - loss: 0.7510 - accuracy: 0.7268
# Epoch 00012: val_accuracy did not improve from 0.70708
# 900/900 [==============================] - 112s 125ms/step - loss: 0.7510 - accuracy: 0.7268 - val_loss: 2.0757 - val_accuracy: 0.4212
# Epoch 13/50
# 900/900 [==============================] - ETA: 0s - loss: 0.7148 - accuracy: 0.7433
# Epoch 00013: val_accuracy did not improve from 0.70708
# 900/900 [==============================] - 113s 125ms/step - loss: 0.7148 - accuracy: 0.7433 - val_loss: 1.0367 - val_accuracy: 0.6288
# Epoch 14/50
# 900/900 [==============================] - ETA: 0s - loss: 0.6866 - accuracy: 0.7540
# Epoch 00014: val_accuracy did not improve from 0.70708
# 900/900 [==============================] - 113s 125ms/step - loss: 0.6866 - accuracy: 0.7540 - val_loss: 0.8434 - val_accuracy: 0.7025
# Epoch 15/50
# 900/900 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.7703
# Epoch 00015: val_accuracy improved from 0.70708 to 0.74667, saving model to ./model.hdf5
# 900/900 [==============================] - 110s 122ms/step - loss: 0.6392 - accuracy: 0.7703 - val_loss: 0.6969 - val_accuracy: 0.7467
# Epoch 16/50
# 900/900 [==============================] - ETA: 0s - loss: 0.6154 - accuracy: 0.7814
# Epoch 00016: val_accuracy did not improve from 0.74667
# 900/900 [==============================] - 110s 122ms/step - loss: 0.6154 - accuracy: 0.7814 - val_loss: 1.0167 - val_accuracy: 0.6950
# Epoch 17/50
# 900/900 [==============================] - ETA: 0s - loss: 0.5784 - accuracy: 0.7926
# Epoch 00017: val_accuracy did not improve from 0.74667
# 900/900 [==============================] - 111s 123ms/step - loss: 0.5784 - accuracy: 0.7926 - val_loss: 1.1429 - val_accuracy: 0.6496
# Epoch 18/50
# 900/900 [==============================] - ETA: 0s - loss: 0.5566 - accuracy: 0.8022
# Epoch 00018: val_accuracy did not improve from 0.74667
# 900/900 [==============================] - 109s 121ms/step - loss: 0.5566 - accuracy: 0.8022 - val_loss: 0.7850 - val_accuracy: 0.7371
# Epoch 19/50
# 900/900 [==============================] - ETA: 0s - loss: 0.5299 - accuracy: 0.8128
# Epoch 00019: val_accuracy improved from 0.74667 to 0.76458, saving model to ./model.hdf5
# 900/900 [==============================] - 115s 127ms/step - loss: 0.5299 - accuracy: 0.8128 - val_loss: 0.6892 - val_accuracy: 0.7646
# Epoch 20/50
# 900/900 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.8279
# Epoch 00020: val_accuracy improved from 0.76458 to 0.77792, saving model to ./model.hdf5
# 900/900 [==============================] - 109s 121ms/step - loss: 0.4899 - accuracy: 0.8279 - val_loss: 0.6634 - val_accuracy: 0.7779
# Epoch 21/50
# 900/900 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.8322
# Epoch 00021: val_accuracy did not improve from 0.77792
# 900/900 [==============================] - 111s 123ms/step - loss: 0.4715 - accuracy: 0.8322 - val_loss: 0.8225 - val_accuracy: 0.7304
# Epoch 22/50
# 900/900 [==============================] - ETA: 0s - loss: 0.4516 - accuracy: 0.8443
# Epoch 00022: val_accuracy did not improve from 0.77792
# 900/900 [==============================] - 108s 121ms/step - loss: 0.4516 - accuracy: 0.8443 - val_loss: 0.6447 - val_accuracy: 0.7692
# Epoch 23/50
# 900/900 [==============================] - ETA: 0s - loss: 0.4184 - accuracy: 0.8523
# Epoch 00023: val_accuracy did not improve from 0.77792
# 900/900 [==============================] - 112s 125ms/step - loss: 0.4184 - accuracy: 0.8523 - val_loss: 0.8070 - val_accuracy: 0.7696
# Epoch 24/50
# 900/900 [==============================] - ETA: 0s - loss: 0.4139 - accuracy: 0.8547
# Epoch 00024: val_accuracy improved from 0.77792 to 0.78542, saving model to ./model.hdf5
# 900/900 [==============================] - 110s 122ms/step - loss: 0.4139 - accuracy: 0.8547 - val_loss: 0.7302 - val_accuracy: 0.7854
# Epoch 25/50
# 900/900 [==============================] - ETA: 0s - loss: 0.3773 - accuracy: 0.8699
# Epoch 00025: val_accuracy improved from 0.78542 to 0.78625, saving model to ./model.hdf5
# 900/900 [==============================] - 114s 127ms/step - loss: 0.3773 - accuracy: 0.8699 - val_loss: 0.6640 - val_accuracy: 0.7862
# Epoch 26/50
# 900/900 [==============================] - ETA: 0s - loss: 0.3871 - accuracy: 0.8667
# Epoch 00026: val_accuracy improved from 0.78625 to 0.79417, saving model to ./model.hdf5
# 900/900 [==============================] - 110s 122ms/step - loss: 0.3871 - accuracy: 0.8667 - val_loss: 0.7307 - val_accuracy: 0.7942
# Epoch 27/50
# 900/900 [==============================] - ETA: 0s - loss: 0.3636 - accuracy: 0.8737
# Epoch 00027: val_accuracy did not improve from 0.79417
# 900/900 [==============================] - 113s 126ms/step - loss: 0.3636 - accuracy: 0.8737 - val_loss: 0.7674 - val_accuracy: 0.7917
# Epoch 28/50
# 900/900 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.8819
# Epoch 00028: val_accuracy did not improve from 0.79417
# 900/900 [==============================] - 109s 121ms/step - loss: 0.3451 - accuracy: 0.8819 - val_loss: 0.7303 - val_accuracy: 0.7821
# Epoch 29/50
# 900/900 [==============================] - ETA: 0s - loss: 0.3402 - accuracy: 0.8839
# Epoch 00029: val_accuracy improved from 0.79417 to 0.79500, saving model to ./model.hdf5
# 900/900 [==============================] - 110s 122ms/step - loss: 0.3402 - accuracy: 0.8839 - val_loss: 0.6977 - val_accuracy: 0.7950
# Epoch 30/50
# 900/900 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.8865
# Epoch 00030: val_accuracy did not improve from 0.79500
# 900/900 [==============================] - 109s 121ms/step - loss: 0.3236 - accuracy: 0.8865 - val_loss: 0.6934 - val_accuracy: 0.7908
# Epoch 31/50
# 900/900 [==============================] - ETA: 0s - loss: 0.3148 - accuracy: 0.8947
# Epoch 00031: val_accuracy improved from 0.79500 to 0.81958, saving model to ./model.hdf5
# 900/900 [==============================] - 110s 123ms/step - loss: 0.3148 - accuracy: 0.8947 - val_loss: 0.5700 - val_accuracy: 0.8196
# Epoch 32/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2923 - accuracy: 0.8998
# Epoch 00032: val_accuracy did not improve from 0.81958
# 900/900 [==============================] - 110s 122ms/step - loss: 0.2923 - accuracy: 0.8998 - val_loss: 0.7593 - val_accuracy: 0.7775
# Epoch 33/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2884 - accuracy: 0.9001
# Epoch 00033: val_accuracy did not improve from 0.81958
# 900/900 [==============================] - 105s 117ms/step - loss: 0.2884 - accuracy: 0.9001 - val_loss: 0.7231 - val_accuracy: 0.7875
# Epoch 34/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2851 - accuracy: 0.9008
# Epoch 00034: val_accuracy did not improve from 0.81958
# 900/900 [==============================] - 110s 122ms/step - loss: 0.2851 - accuracy: 0.9008 - val_loss: 0.6463 - val_accuracy: 0.8050
# Epoch 35/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2659 - accuracy: 0.9060
# Epoch 00035: val_accuracy did not improve from 0.81958
# 900/900 [==============================] - 110s 122ms/step - loss: 0.2659 - accuracy: 0.9060 - val_loss: 0.6463 - val_accuracy: 0.8087
# Epoch 36/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2741 - accuracy: 0.9069
# Epoch 00036: val_accuracy did not improve from 0.81958
# 900/900 [==============================] - 110s 123ms/step - loss: 0.2741 - accuracy: 0.9069 - val_loss: 1.1214 - val_accuracy: 0.6917
# Epoch 37/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.9144
# Epoch 00037: val_accuracy improved from 0.81958 to 0.82792, saving model to ./model.hdf5
# 900/900 [==============================] - 112s 124ms/step - loss: 0.2510 - accuracy: 0.9144 - val_loss: 0.5947 - val_accuracy: 0.8279
# Epoch 38/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.9126
# Epoch 00038: val_accuracy did not improve from 0.82792
# 900/900 [==============================] - 105s 116ms/step - loss: 0.2563 - accuracy: 0.9126 - val_loss: 0.6754 - val_accuracy: 0.8004
# Epoch 39/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2321 - accuracy: 0.9230
# Epoch 00039: val_accuracy did not improve from 0.82792
# 900/900 [==============================] - 112s 124ms/step - loss: 0.2321 - accuracy: 0.9230 - val_loss: 0.7518 - val_accuracy: 0.8021
# Epoch 40/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9232
# Epoch 00040: val_accuracy did not improve from 0.82792
# 900/900 [==============================] - 111s 124ms/step - loss: 0.2217 - accuracy: 0.9232 - val_loss: 0.7026 - val_accuracy: 0.8208
# Epoch 41/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.9212
# Epoch 00041: val_accuracy did not improve from 0.82792
# 900/900 [==============================] - 112s 125ms/step - loss: 0.2316 - accuracy: 0.9212 - val_loss: 0.6505 - val_accuracy: 0.8167
# Epoch 42/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9217
# Epoch 00042: val_accuracy improved from 0.82792 to 0.83542, saving model to ./model.hdf5
# 900/900 [==============================] - 105s 117ms/step - loss: 0.2260 - accuracy: 0.9217 - val_loss: 0.6313 - val_accuracy: 0.8354
# Epoch 43/50
# 900/900 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9294
# Epoch 00043: val_accuracy did not improve from 0.83542
# 900/900 [==============================] - 112s 124ms/step - loss: 0.2144 - accuracy: 0.9294 - val_loss: 0.8910 - val_accuracy: 0.7750
# Epoch 44/50
# 900/900 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9340
# Epoch 00044: val_accuracy did not improve from 0.83542
# 900/900 [==============================] - 113s 126ms/step - loss: 0.1947 - accuracy: 0.9340 - val_loss: 0.7565 - val_accuracy: 0.8112
# Epoch 45/50
# 900/900 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9316
# Epoch 00045: val_accuracy improved from 0.83542 to 0.84167, saving model to ./model.hdf5
# 900/900 [==============================] - 114s 127ms/step - loss: 0.1996 - accuracy: 0.9316 - val_loss: 0.5842 - val_accuracy: 0.8417
# Epoch 46/50
# 900/900 [==============================] - ETA: 0s - loss: 0.1950 - accuracy: 0.9340
# Epoch 00046: val_accuracy did not improve from 0.84167
# 900/900 [==============================] - 113s 125ms/step - loss: 0.1950 - accuracy: 0.9340 - val_loss: 0.6095 - val_accuracy: 0.8333
# Epoch 47/50
# 900/900 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9367
# Epoch 00047: val_accuracy did not improve from 0.84167
# 900/900 [==============================] - 106s 118ms/step - loss: 0.1882 - accuracy: 0.9367 - val_loss: 0.7847 - val_accuracy: 0.7937
# Epoch 48/50
# 900/900 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9385
# Epoch 00048: val_accuracy did not improve from 0.84167
# 900/900 [==============================] - 113s 125ms/step - loss: 0.1802 - accuracy: 0.9385 - val_loss: 0.9884 - val_accuracy: 0.7496
# Epoch 49/50
# 900/900 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9376
# Epoch 00049: val_accuracy did not improve from 0.84167
# 900/900 [==============================] - 113s 126ms/step - loss: 0.1820 - accuracy: 0.9376 - val_loss: 0.7268 - val_accuracy: 0.8012
# Epoch 50/50
# 900/900 [==============================] - ETA: 0s - loss: 0.1624 - accuracy: 0.9458
# Epoch 00050: val_accuracy did not improve from 0.84167
# 900/900 [==============================] - 114s 127ms/step - loss: 0.1624 - accuracy: 0.9458 - val_loss: 0.6805 - val_accuracy: 0.8108

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
img=plt.imread('../input/deepweedsx/DeepWeeds_Images_256/20170718-095159-2.jpg')
img=np.array(img)
img=img.reshape(1,256,256,3)

# %%
model.predict(img)
# Out:
# array([[6.2391394e-01, 7.0754490e-03, 2.2918903e-04, 8.1082568e-02,
#         3.2543961e-02, 4.4320775e-03, 3.6460002e-05, 1.0719189e-01,
#         1.4349444e-01]], dtype=float32)
